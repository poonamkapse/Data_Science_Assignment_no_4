# %%
#######################################Delivery Dataset##################################################################

# %%
#importing dataset
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
import statsmodels.formula.api as smf
from sklearn.metrics import r2_score
import seaborn as sns

# %%
data1 = pd.read_csv('delivery_time.csv')
data1.head()
# Out:
#    Delivery_Time  Sorting_Time
# 0          21.00            10
# 1          13.50             4
# 2          19.75             6
# 3          24.00             9
# 4          29.00            10

# %%
plt.figure(figsize=(20,7),facecolor="lightgreen")
plt.scatter(data1['Delivery_Time'],data1['Sorting_Time'])
plt.xlabel("Delivery_Time")
plt.ylabel("Sorting _Time")
plt.show()

# %%
sns.distplot(data1['Delivery_Time'])
# Out:
# C:\Users\LENOVO\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Delivery_Time', ylabel='Density'>

# %%
sns.distplot(data1['Sorting_Time'])
# Out:
# C:\Users\LENOVO\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Sorting_Time', ylabel='Density'>

# %%
#data preprocessing
X =data1.iloc[:, :-1].values
Y = data1.iloc[:,1].values #dependent vsriable vector

# %%
#splitting the dataset
X_train, X_test,Y_train,Y_test = train_test_split(X,Y,test_size=1/4,random_state=0)

# %%
#fitting the regression model
regressor = LinearRegression()
regressor.fit(X_train,Y_train) #actually produces the linear equation for
# Out:
# LinearRegression()

# %%
#predicting the test set results
Y_pred = regressor.predict(X_test)
Y_pred
# Out:
# array([6.70508055, 4.01071688, 8.22066012, 4.85270553, 3.69497114,
#        7.5175996 ])

# %%
Y_test
# Out:
# array([10,  3,  5,  4,  4,  8], dtype=int64)

# %%
#Visualizing the results
#plot the train
plt.scatter(X_train,Y_train,color ='red') #plotting the observations
plt.plot(X_train,regressor.predict(X_train),color='blue')
plt.title("Delivery Time vs Sorting Time")
# Out:
# Text(0.5, 1.0, 'Delivery Time vs Sorting Time')

# %%
#plot for test 
plt.scatter(X_test,Y_test,color='red')
plt.plot(X_train, regressor.predict(X_train), color='blue') # plotting the regression line
plt.title("Delivery Time vs Sorting Time  (Testing set)")
plt.xlabel("Delivery Time",color='black') 
plt.ylabel("Sorting Time",color='black') 
#plt.xlim(0,30)
#plt.ylim(0,20)
plt.show()

# %%
##################################################salary data set############################################################

# %%
data2 =pd.read_csv('Salary_Data.csv')
data2.head()
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0

# %%
data2.isnull().sum()
# Out:
# YearsExperience    0
# Salary             0
# dtype: int64

# %%
data2.duplicated().sum()
# Out:
# 0

# %%
sns.distplot(data2['YearsExperience'])
# Out:
# C:\Users\LENOVO\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='YearsExperience', ylabel='Density'>

# %%
sns.distplot(data2['Salary'])
# Out:
# C:\Users\LENOVO\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Salary', ylabel='Density'>

# %%
plt.figure(figsize=(20,7),facecolor="lightgreen")
plt.scatter(data2['YearsExperience'],data2['Salary'])
plt.xlabel("YearsExperience")
plt.ylabel("Salary")
plt.show()

# %%
#data preprocessing
X =data2.iloc[:, :-1].values
Y = data2.iloc[:,1].values #dependent variable vector

# %%
#splitting the dataset
from sklearn.model_selection import train_test_split
X_train, X_test,Y_train,Y_test = train_test_split(X,Y,test_size=1/4,random_state=23)

# %%
#fitting the regression model
regressor = LinearRegression()
regressor.fit(X_train,Y_train) #actually produces the linear equation for
regressor
# Out:
# LinearRegression()

# %%
#predicting the test set results
Y_pred = regressor.predict(X_test)
Y_pred
# Out:
# array([ 74074.15619481,  90067.27540512,  62784.89557576,  72192.6127583 ,
#         92889.59055988,  46791.77636544, 107941.93805194,  38324.83090116])

# %%
Y_test
# Out:
# array([ 66029.,  91738.,  63218.,  67938.,  98273.,  39891., 109431.,
#         46205.])

# %%
Y_train
# Out:
# array([ 43525., 116969.,  83088.,  81363.,  39343.,  61111.,  56642.,
#         55794.,  37731., 105582., 113812., 122391., 121872.,  54445.,
#         56957.,  57081., 112635., 101302.,  57189.,  64445.,  60150.,
#         93940.])

# %%
#Visualizing the results
#plot the train
plt.scatter(X_train,Y_train,color ='red') #plotting the observations
plt.plot(X_train,regressor.predict(X_train),color='blue')
plt.title("Years of Experience Vs Salary")
# Out:
# Text(0.5, 1.0, 'Years of Experience Vs Salary')

# %%
#plot for test 
plt.scatter(X_test,Y_test,color='red')
plt.plot(X_train, regressor.predict(X_train), color='blue') # plotting the regression line
plt.title(" Years of Experience Vs Salary (Testing set)")
plt.xlabel("Yearsof Experience",color='black') 
plt.ylabel("Salary",color='black') 
#plt.xlim(0,30)
#plt.ylim(0,10)
plt.show()
